# %% [markdown]
# # Nidhi OK

# %%
import math # Change
print("***** WELCOME ******")
print("please choose the required operation to be performed")
rop=eval(input('''ENTER + : ADDITION
ENTER -: SUBRACTION
ENTER *: MULTIPLICATION
ENTER /: DIVISION
ENTER ** :SQAURE NO
ENTER ***: CUBE NO
ENTER cubrt: CUBE ROOT OF A NUMBER
ENTER sqrt: SQAURE ROOT OF A NUMBER
ENTER TAN , SIN ,COS : TANGENT, SINE ,COSINE
;'''))

num1=eval(input("please enter the number"))
num2=eval(input("please enter the number"))

if rop == '+' :
    print("the addition of the given number is",num1+num2)
    
elif rop == '-' :
    print(" the subraction of the given numbers is ",num1-num2)
elif rop == '*':
    print("the multiplication of the given numbers is ",num1*num2)
elif rop== '/' :
    print("the division of given numbers is ",num1/num2)
elif rop== '**':
    print("the sqaure of a given number is ",num1**2)
elif rop== '***' :
    print("the cube of a given number is ",num1**3)
elif rop== 'cubrt' :
    print("the cube root of a given number is ",num1**(1./3))
elif rop== 'sqrt':
    print("the square root of a given number is ",math.pow(num1,0.5))
elif rop== 'tan':
    print("the tangent value of a given number is ",math.tan(num1))
elif rop== 'sin':
    print("the sine value of a given number is ",math.sine(num1))
elif rop== 'cos':
    print("the cosine value of a given number is ",math.cos(num1))
else:
    print("oops invalid operation")
print("****** THANKYOU****** ")
# Out:
# ***** WELCOME ******
# please choose the required operation to be performed
# the addition of the given number is 10
# ****** THANKYOU******

# %% [markdown]
# # Mansi OK

# %% [markdown]
# ## ZeroError

# %%
# calculator
import math
print(" ELEMENTARY CALCULATOR")
print("ADDITION = 1          SUBSTRACTION = 2           MULTIPLICATION = 3       DIVISION = 4")
print("SQUARE = 5            CUBE = 6                   SQUARE ROOT = 7          CUBE ROOT = 8")
print("trigonometry = 9      inverse trigonometry= 10")
x = int(input())
a = 0
b = 0
y = 0
t = 0
ans = 0
ch = 'null'
if x == 1 or x == 2 or x == 3 or x == 4:
    print("please enter the two numbers : ", end=" ")
    a = float(input("1st :"))
    b = float(input("2nd :"))
elif x == 5 or x == 6 or x == 7 or x == 8:
    print("please enter the value : ", end=" ")
    a = int(input())
elif x == 9 or x == 10:
    print("sin x = 'sin'          cos x = 'cos'       tan x = 'tan'")
    print("cosec x = 'cosec'      sec x = 'sec'       cot x = 'cot'")
    print("sin-1 x = 'sini'       cos-1 x = 'cosi'    tan-1 x = 'tani'")
    print("cosec-1 x = 'coseci'   sec-1 x = 'seci'    cot-1 x = 'coti'")
    print("please enter the trigonometry function : ", end=" ")
    ch = input()
    print("for inverse function range is -1 to 1, value out of range will give an error")
    t = float(input("enter the angle or value if its inverse :"))
    y = math.degrees(t)
    print("in degree :", y)
else:
    print("invalid !!!")

if x == 1:
    ans = a+b
    print("addition :", ans)
elif x == 2:
    ans = a - b
    print("substraction :", ans)
elif x == 3:
    ans = a * b
    print("multiplication :", ans)
elif x == 4:
    ans = a / b
    print("division :", ans)
elif x == 5:
    ans = a*a
    print("square of %d :" % a, ans)
elif x == 6:
    ans = math.pow(a, 3)
    print("cube of %d :" % a, ans)
elif x == 7:
    ans = math.pow(a, 1/2)
    print("square  root of %d :" % a, ans)
elif x == 8:
    ans = math.pow(a, 1/3)
    print("cube root of %d :" % a, ans)
elif x == 9 or x == 10:
    if ch == 'sin':
        ans = math.sin(t)
    elif ch == 'cos':
        ans = math.cos(t)
    elif ch == 'tan':
        ans = math.tan(t)
    elif ch == 'sec':
        ans = 1/(math.cos(t))
    elif ch == 'cosec':
        ans = 1/(math.sin(t))
    elif ch == 'cot':
        ans = 1/(math.tan(t))
    elif ch == 'sini':
        ans = math.asin(t)
    elif ch == 'cosi':
        ans = math.acos(t)
    elif ch == 'tani':
        ans = math.atan(t)
    elif ch == 'seci':
        ans = math.acos(1/t)
    elif ch == 'coseci':
        ans = math.asin(1/t)
    elif ch == 'coti':
        ans = math.atan(1/t)
    else:
        print("no such trigonometric function!!")
    print("the value of %s function :" % ch, ans)
else:
    print("invalid option !!!")

# %% [markdown]
# # Aarav OK

# %% [markdown]
# ## ZeroError Insufficient Info

# %%
import math

print("Enter 1 for basicops and 2 for logicops you want to get...") #choose type of calculation you want to do,,,
getops=int(input())

 
if getops==1:     # for Basic operations

    basicops=("1.1 Addition ",
        "1.2Substarction ",
       "1.3Multiplication ",
          "1.4.Division ",
          "1.5 Modulas")
          
    print(basicops)
    print("Please enter first number..")  
    inpnum=input()
    print("Please enter num 2:")
    indnum=input()
    print("Enter the type of operatin you want to get...") 
    inop=float(input())

    

    if inop==1.1:
        print("Sum of both num is:" ,int(inpnum)+int(indnum))

    elif inop==1.2:
        print("Difference of both num is:" ,int(inpnum)-int(indnum))
    elif inop==1.3:    
        print("Product of both num is:" ,int(inpnum)*int(indnum))
    elif inop==1.4:     
        print("Division of both num gives:" ,int(inpnum)/int(indnum))
    elif inop==1.5:     
        print("Mode of both num is:" ,int(inpnum)%int(indnum))

if getops==2:       # for logic operations

    logicops=("2.1 Square ",
            "2.2 Cube ",
            "2.3 Square root",
            "2.4 trignofuncs ")

    print(logicops)
    print("If you wnat any trignomatric value then please enter any angle else anter any number :")
    inplog=int(input())      
           
    print("Enter the type of operatin you want to get...")
    logop=float(input())

    if logop==2.1:
        print("Square of eneterd number is:" ,int(inplog)**2)
    elif logop==2.2:
        print("Cube of eneterd number is:" ,int(inplog)**3)
    elif logop==2.3:    
        print("Square root of eneterd number is:" ,int(math.sqrt(inplog)))
    elif logop==2.4:     
        print("Tringnometric value of enetered angle is:" , math.sin(math.radians(inplog)) ,math.cos(math.radians(inplog)), math.tan(math.radians(inplog)))

# %% [markdown]
# # Chetan OK PERFECT

# %% [markdown]
# ## ZeroError

# %%
# Program to make a simple calculator

#This function adds two numbers
def add(x,y):
	return x+y
	 
#This function substract two numbers
def substract(x,y):
	return x-y
	
#This function multiply two numbers
def multiply(x,y):
	return x*y
	
#This function divides two numbers
def divide (x,y):
	return x/y
	
#This function provide square of the number
def square(x):
    num=x**2
    return num
	
#This function provide cube of the number
def cube(x):
	return x**3
	
#This function provide square root of the number
def squareroot(x):
	return x**0.5
	
#This function provide cube root of the number
def cuberoot(x):
	return x**(1/3)
	
print('select operation')
print('1.add')
print('2.subtract')
print('3.multiply')
print('4.divide')
print('5.square')
print('6.cube')
print('7.square root')
print('8.cube root')

while True:
    #Take input from user
    choice=input("Enter choice(1/2/3/4/5/6/7/8): ")

    #Check if choice is one of eight operations
    if choice in ('1','2','3','4','5','6','7','8'):
        if choice=='1':
            num1=float(input('Enter first num: '))
            num2=float(input('Enter second num: '))
            print(num1,'+',num2,'=',add(num1,num2))
 
        elif choice=='2':
            num1=float(input('Enter first num: '))
            num2=float(input('Enter second num: '))
            print(num1,'-',num2,'=',substract(num1,num2))

        elif choice=='3':
            num1=float(input('Enter first num: '))
            num2=float(input('Enter second num: '))
            print(num1,'*',num2,'=',multiply(num1,num2))

        elif choice=='4':
            num1=float(input('Enter first num: '))
            num2=float(input('Enter second num: '))
            print(num1,'/',num2,'=',divide(num1,num2))

        elif choice=='5':
            num=float(input('Enter num: '))
            print('square is',square(num))
 
        elif choice=='6':
            num=float(input('Enter num: '))
            print('cube is',cube(num))

        elif choice=='7':
            num=float(input('Enter num: '))
            print('square root is',squareroot(num))

        elif choice=='8':
            num=float(input('Enter num: '))
            print('cube root is',cuberoot(num))
        break
    else:
        print("Invalid input")

# %% [markdown]
# # Aarti OK

# %% [markdown]
# ## ZeroError

# %%
# to make simple calculator

num1 = int(input("Enter first number"))
print(num1)
num2 = int(input("Enter second number"))
print(num2)
op = input("Enter operation")
print(op)

if op == "+":
    print(num1 + num2)

elif op == "-":
    print(num1 - num2)

elif op == "*":
    print(num1 * num2)

elif op == "/":
    print(num1 / num2)

elif op == "**":
    print(num1 ** num2)

else:
    print("Invalid operation")

# %% [markdown]
# # Harsh Kesarwani

# %%
 # write a program to do basic calculation
#for addition
def add(x,y):
    return x+y

#for substruction
def substruct(x,y):
    return x-y

#for multiplication
def multiply(x,y):
    return x*y

#for division
def divide(x,y):
    return x/y

#for square/cube of a number
def sqcu(x,y):
    return x**y

#for squareroot
def squareroot(x):
    return x**0.5

#for cuberoot
def cuberoot(x):
    return x**(1/3)

print("select operation\n 1.addition\n 2.substruction\n 3.multiplication\n 4.division\n 5.square or cude of a number\n 6.square root\n 7.cube root\n")
while True:
    #take input from user
    choice=input("enter a choice (1/2/3/4/5/6/7) : ")

    #check if choice is one of seven operation
    if choice in ('1','2','3','4','5','6','7'):
        if choice=='1':
            x=float(input("enter a first : "))
            y=float(input("enter a second : "))
            print(x,'+',y,'=',add(x,y))
        
        elif choice=='2':
            x=float(input("enter a first : "))
            y=float(input("enter a second : "))
            print(x,'-',y,'=',substruct(x,y))
        
        elif choice=='3':
            x=float(input("enter a first : "))
            y=float(input("enter a second :"))
            print(x,'x',y,'=',multiply(x,y))

        elif choice=='4':
            x=float(input("enter a first : "))
            y=float(input("enter a second :"))
            print(x,'/',y,'=',divide(x,y))

        elif choice=='5':
            x=float(input("enter a first : "))
            y=float(input("enter a ('2'/'3') :"))
            print(x,'is time of',y,'is',sqcu(x,y))

        elif choice=='6':
            x=float(input("enter a number : "))
            print('square root of',x,'is',squareroot(x))

        elif choice=='7':
            x=float(input("enter a number : "))
            print('cube root of',x,'is',cuberoot(x))
        break
    else:
        print("invaild input!!!")
# Out:
# select operation
#  1.addition
#  2.substruction
#  3.multiplication
#  4.division
#  5.square or cude of a number
#  6.square root
#  7.cube root
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-8-8a3736cea84b> in <module>
#      53            x=float(input("enter a first : "))
#      54            y=float(input("enter a second :"))
# ---> 55            print(x,'/',y,'=',divide(x,y))
#      56
#      57        elif choice=='5':
#
# <ipython-input-8-8a3736cea84b> in divide(x, y)
#      14 #for division
#      15 def divide(x,y):
# ---> 16    return x/y
#      17
#      18 #for square/cube of a number
#
# ZeroDivisionError: float division by zero
